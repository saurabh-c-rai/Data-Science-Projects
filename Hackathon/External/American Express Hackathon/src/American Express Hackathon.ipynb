# %%
import numpy as np
import pandas as pd

# %%
train_path = '/Users/raisaurabh04/OneDrive/GreyAtom/Practice Dataset/American Express Hackathon/train/train.csv'

# %%
pd.read_csv(train_path)
# Out:
#            id  campaign_id  coupon_id  customer_id  redemption_status
# 0           1           13         27         1053                  0
# 1           2           13        116           48                  0
# 2           6            9        635          205                  0
# 3           7           13        644         1050                  0
# 4           9            8       1017         1489                  0
# 5          11           11        795          793                  0
# 6          14            9        444          590                  0
# 7          15           29        538          368                  0
# 8          17           30        857          523                  0
# 9          19            2        559          679                  0
# 10         20            9        575          108                  0
# 11         21           13       1028           89                  0
# ...
