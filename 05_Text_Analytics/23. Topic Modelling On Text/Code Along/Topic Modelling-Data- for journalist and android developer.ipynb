# %%
# !python -m spacy download en
# nltk.download('stopwords') # run this one time

# %% [markdown]
# ### Resume tailoring
#
# A company has a requirement for two job roles i.e Android Developer and Journalist. And your manager wants you to do some basic analysis for him.
#
# For most job openings, a particular skill set is desired to perform specific tasks. Tailoring your resume is about recognizing those skills and responsibilities on the job description and making it obvious that you’re up to the task. Your company's goal is to draw the shortest line possible between your experience and what’s stated in the job description.
#
# Tailoring your resume connects the dots for recruiters and hiring managers who are overwhelmed by a flood of generic applicants. Instead of proving that you’re an experienced professional in general, it shows them that you’re a perfect fit for this specific job.
#
#
#
#
# ### About the dataset
# When performing data science tasks, it’s common to use data found on the internet. You’ll usually be able to access this data in CSV format, or via an Application Programming Interface (API). However, there are times when the data you want can only be accessed as part of a web page. In cases like this, you’ll want to use a technique called web scraping to get the data from the web page into a format you can work within your analysis.
#
# You need to perform Topic Modelling on the given data and extract useful topics that will help your manager to short list the candidates based on the topics for a specified job role.
#
# The scraped data is been provided to you in the form of `csv`.
#
# |Feature|Description|
# |-----|-----|
# |company| Name of the company|
# |job| job title|
# |job_desc| description of jobs|
# |location|job locaton|
# |url|Link of the jobs from it was scraped|
# |job_type|type of the job|

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import re
import spacy
import gensim
from gensim import corpora
pd.set_option("display.max_colwidth", 200)


import operator
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

import nltk
from nltk.stem import WordNetLemmatizer
from string import punctuation
from nltk.tokenize import word_tokenize
from collections import Counter
import operator

# libraries for visualization
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading the dataset

# %%
jobs = pd.read_csv("merged_indeed_new.csv")
jobs.head()
# Out:
#                         company                                  job  \
# 0                   Micro Focus                  Core Java Developer
# 1  MS Clinical Research (P) Ltd                Android App Developer
# 2        Applied Materials Inc.  Software Engineer – Unity Developer
# 3                  Shaw Academy                Lead Mobile Developer
# 4    Letsgettin Private Limited          Android Developer- Freshers
#
#                                                                                                                                                                                                   job_desc  \
# 0  Core Java Developer\r\r\n\r\r\nJob Description:\r\r\n\r\r\nAt Micro Focus, everything we do is based on a simple idea: The fastest way to get results is to build on what you have. Our software sol...
# 1  Job Summary\r\r\nOver 3 years experience designing, developing, integrating, and supporting Android App development\r\r\nApply in-depth understanding of business and IT requirements to streamline ...
# 2  Company Introduction\r\r\nApplied Materials , Inc. is the global leader in materials engineering solutions for the semiconductor, flat panel display and solar photovoltaic (PV) industries. applied...
# 3  Senior Mobile App Developer/Lead (Android or iOS)\r\r\nShaw Academy is seeking a Mobile Development Lead, initially to be the hands-on coder for our apps and then to build a team aroundyou. The ro...
# 4  Job Summary\r\r\nPosition: Android developer\r\r\nEducation: Bachelor's\r\r\nRequired candidates: Freshers\r\r\nResponsibilities and Duties\r\r\nDesign and build advanced applications for the Andr...
#
#     location  \
# 0  Bangalore
# 1  Bangalore
# 2  Bangalore
# 3  Bangalore
# 4  Bangalore
#
#                                                                                                                                                                                                        url  \
# 0  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6NYlbfkN0BduEgvIgdT7EDM_O2GxHkw7QoaouEWjxefAvaX3ZwZ9tYBt705y4baMnhcBFo_61Er-rE59t0DIcl816jpSPhQlE2-XsX8ZtBLxXVsMZdq8VWbZfs3uXN1oqCxQ7zxUL2JTHVmAEZthPEL...
# 1  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6NYlbfkN0BduEgvIgdT7EDM_O2GxHkw7QoaouEWjxefAvaX3ZwZ9tYBt705y4baMnhcBFo_61Er-rE59t0DIcl816jpSPhQlE2-XsX8ZtBLxXVsMZdq8VWbZfs3uXN1oqCxQ7zxUL2JTHVmAEZthPEL...
# 2  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6NYlbfkN0BduEgvIgdT7EDM_O2GxHkw7QoaouEWjxefAvaX3ZwZ9tYBt705y4baMnhcBFo_61Er-rE59t0DIcl816jpSPhQlE2-XsX8ZtBLxXVsMZdq8VWbZfs3uXN1oqCxQ7zxUL2JTHVmAEZthPEL...
# 3  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6NYlbfkN0BduEgvIgdT7EDM_O2GxHkw7QoaouEWjxefAvaX3ZwZ9tYBt705y4baMnhcBFo_61Er-rE59t0DIcl816jpSPhQlE2-XsX8ZtBLxXVsMZdq8VWbZfs3uXN1oqCxQ7zxUL2JTHVmAEZthPEL...
# 4  https://www.indeed.co.in/pagead/clk?mo=r&ad=-6NYlbfkN0BduEgvIgdT7EDM_O2GxHkw7QoaouEWjxefAvaX3ZwZ9tYBt705y4baMnhcBFo_61Er-rE59t0DIcl816jpSPhQlE2-XsX8ZtBLxXVsMZdq8VWbZfs3uXN1oqCxQ7zxUL2JTHVmAEZthPEL...
#
#             job_type
# 0  Android Developer
# 1  Android Developer
# 2  Android Developer
# 3  Android Developer
# 4  Android Developer

# %% [markdown]
# ### Drop unnecessary Columns
#
# For the analysis of the job description, we are only interested in the text data associated with the jobs. We will analyze this text data using natural language processing. Since the file contains some metadata such as company, location and url. It is necessary to remove all the columns that do not contain useful text information.

# %%
jobs.drop(columns=['company', 'location', 'url'], inplace=True)

# %%
jobs.head()
# Out:
#                                    job  \
# 0                  Core Java Developer
# 1                Android App Developer
# 2  Software Engineer – Unity Developer
# 3                Lead Mobile Developer
# 4          Android Developer- Freshers
#
#                                                                                                                                                                                                   job_desc  \
# 0  Core Java Developer\r\r\n\r\r\nJob Description:\r\r\n\r\r\nAt Micro Focus, everything we do is based on a simple idea: The fastest way to get results is to build on what you have. Our software sol...
# 1  Job Summary\r\r\nOver 3 years experience designing, developing, integrating, and supporting Android App development\r\r\nApply in-depth understanding of business and IT requirements to streamline ...
# 2  Company Introduction\r\r\nApplied Materials , Inc. is the global leader in materials engineering solutions for the semiconductor, flat panel display and solar photovoltaic (PV) industries. applied...
# 3  Senior Mobile App Developer/Lead (Android or iOS)\r\r\nShaw Academy is seeking a Mobile Development Lead, initially to be the hands-on coder for our apps and then to build a team aroundyou. The ro...
# 4  Job Summary\r\r\nPosition: Android developer\r\r\nEducation: Bachelor's\r\r\nRequired candidates: Freshers\r\r\nResponsibilities and Duties\r\r\nDesign and build advanced applications for the Andr...
#
#             job_type
# 0  Android Developer
# 1  Android Developer
# 2  Android Developer
# 3  Android Developer
# 4  Android Developer

# %% [markdown]
# ###  Calculate the number of jobs for each job type.

# %%
jobs.groupby('job_type')['job'].value_counts()
# Out:
# job_type                   job
# Android Developer          Android Developer                                                          30
#                            Android App Developer                                                       3
#                            Android Application Developer                                               2
#                            Junior Android Developer                                                    2
#                            Android & PHP Software Developer                                            1
#                            Android - Mobile Developer                                                  1
#                            Android Developer (Trainee)                                                 1
#                            Android Developer Required                                                  1
#                            Android Developer for Pune, Hinjewadi office                                1
#                            Android Developer- Freshers                                                 1
#                            Android Developer/iOS App Developer                                         1
#                            Android developer                                                           1
#                            Apps Systems Engineer 5                                                     1
#                            Core Java Developer                                                         1
#                            Dot Net Developer in Flight/Hotel Api Integration                           1
#                            Experienced .net developer and android developer required Full time JOB     1
#                            IBM Worklight (MobileFirst) Mobile Application Developer                    1
#                            IBM Worklight Developer                                                     1
#                            Immediate Joiner required-Android developer                                 1
#                            Java, J2EE, Javascript, Mobile Developer (PHP developers can apply)         1
#                            Job opening for Android Developer (Warje)                                   1
#                            Jr. Android Developer                                                       1
#                            Lead Mobile Developer                                                       1
#                            Mobile App Developer (Cordova, Android, iOS)                                1
#                            Mobile App Developer 1-3 years of experience                                1
#                            Osmosys Software - Android Developer - Cordova/Ionic - Exp: 1yr             1
#                            PHP Laravel Developer                                                       1
#                            Progressive Web Apps Developer                                              1
#                            Senior Android Developer                                                    1
#                            Software Developer - (.NetMVC) (PHP Codigniter) (Android)                   1
#                                                                                                       ..
# Machine Learning Engineer  Inside Sales Associate (B.Tech only)                                        1
#                            Integrated Software Systems Engineer (Associate)                            1
#                            Java Full Stack Developer / Core Java / HTML / Java Script / Cloud          1
#                            Junior Data Scientist/Teaching Assistant                                    1
#                            ML Engineer II                                                              1
#                            ML Specialist SA                                                            1
#                            Machine Learning                                                            1
#                            Machine Learning Developer                                                  1
#                            Machine Learning Engineer ( Pune + 73771 )                                  1
#                            Machine Learning Engineer - 1                                               1
#                            Machine Learning QA Engineer                                                1
#                            Machine Learning Specialist                                                 1
#                            Machine-learning Engineer                                                   1
#                            Professional - Data Analytics                                               1
#                            QA Engineer                                                                 1
#                            Quality Engineer Associate-Machine Learning                                 1
#                            Research Engineer - Deep Learning                                           1
#                            SOFTWARE ENGINEER – DATA & MACHINE LEARNING                                 1
#                            SSC Data APS - Support Analyst                                              1
#                            Senior Business Analyst                                                     1
#                            Senior Design Engineer                                                      1
#                            Senior DevOps Engineer                                                      1
#                            Senior Software Engineer- Big/Data & Machine Learning                       1
#                            Software Development Engineer                                               1
#                            Software Development Engineer (Data) - Ad Platfrom                          1
#                            Software Engineer                                                           1
#                            Software Engineer Python, Machine Learning/AI                               1
#                            Software Engineer, Speech Recognition/Machine Learning (Bangalore)          1
#                            Sr. Python Developer(Machine Learning Developer),Pune.                      1
#                            Workfusion Machine Learning Engineer                                        1
# Name: job, Length: 404, dtype: int64

# %%
jobs['job'].value_counts()
# Out:
# Android Developer                                                      30
# Data Scientist                                                         24
# Front End Developer                                                    21
# iOS Developer                                                          18
# Machine Learning Engineer                                              14
# Full Stack Developer                                                   14
# Backend Developer                                                      12
# Data Analyst                                                            9
# Full Stack Web Developer                                                7
# Web Developer                                                           6
# Software Engineer                                                       6
# Research Analyst                                                        6
# PHP Developer                                                           6
# Market Research Analyst                                                 4
# Front End Web Developer                                                 4
# Researcher and Analyst                                                  4
# IOS Developer                                                           4
# Full Stack Lead Data Scientist(Machine Learning/Computer Vision)        3
# Software Engineer - Machine Learning                                    3
# Sr. Full Stack Engineer                                                 3
# Software Developer - Backend                                            3
# iOS Application Developer                                               3
# Business Analyst                                                        3
# Junior Data Scientist/Teaching Assistant                                3
# Senior Data Analyst                                                     3
# Android App Developer                                                   3
# MEAN Stack Developer                                                    3
# UI- Front End Developer                                                 3
# Lead Mobile Developer                                                   3
# Data Scientist- Quant                                                   2
#                                                                        ..
# Research Analyst/ Data Intern                                           1
# Sr. Copy Writer                                                         1
# Node.js Backend Developer                                               1
# Data Scientist - Machine Learning Engineer                              1
# Machine Learning/Data Scientist                                         1
# Junior Business Analyst/Business Analyst                                1
# Android - Mobile Developer                                              1
# Executive - Data Research & Lead Generation                             1
# Media Relations                                                         1
# Principal Data Scientist                                                1
# Subtitle Analyst - English/Telugu - Banjara Hills                       1
# FinOps Analyst - AR                                                     1
# Video Journalist                                                        1
# Software Developer (Frontend) - L1/L2/L3                                1
# Mulesoft Cloudhub                                                       1
# Journalist&Chief Editor - MAD Design Magazine                           1
# Research Analyst / Sr Research Analyst - Oil & Gas / Energy & Power     1
# Senior Java Developer                                                   1
# Software Engineer Python, Machine Learning/AI                           1
# Associate Data Analyst                                                  1
# Front End Developer- Angular JS 1.x                                     1
# Android Developer- Freshers                                             1
# AGM - Corporate Communication                                           1
# Digital Marketing                                                       1
# Software Architect                                                      1
# Full Stack UI Developer                                                 1
# Manager—Corporate Communication                                         1
# JAVA /UI DEVELOPER                                                      1
# News Reporter (Journalist)                                              1
# SAP BW (Business Warehouse)                                             1
# Name: job, Length: 353, dtype: int64

# %% [markdown]
# ### Subset the jobs(i.e Android Developer & Journalist) based on job_type. And store only job_desc based on job type.
#
# Further analysis will be done only on `job_desc` column.

# %%
jobs[jobs['job_type'] == 'Android Developer']
# Out:
#                                                                         job  \
# 0                                                       Core Java Developer
# 1                                                     Android App Developer
# 2                                       Software Engineer – Unity Developer
# 3                                                     Lead Mobile Developer
# 4                                               Android Developer- Freshers
# 5                                                         Android Developer
# 6                                                         Android Developer
# 7                                                         Android Developer
# 8                                                         Android Developer
# 9                                                         Android Developer
# 10                                                    Android App Developer
# 11                                                        Android Developer
# 12                                                        Android developer
# 13                                                        Android Developer
# 14                                                 Senior Android Developer
# 15                                         Android & PHP Software Developer
# 16                                                    PHP Laravel Developer
# 17                                               Android - Mobile Developer
# 18                                     Urgent Opening for Android Developer
# 19                                              Android Developer (Trainee)
# 20                                                        Android Developer
# 21                                            Android Application Developer
# 22                                                        Android Developer
# 23                                                        Android Developer
# 24                                                        Android Developer
# 25                                                        Android Developer
# 26                                                    Sr. Android Developer
# 27                                            Android Application Developer
# 28                                                  Apps Systems Engineer 5
# 29                                           Progressive Web Apps Developer
# ..                                                                      ...
# 40                                                        Android Developer
# 41                                               Software Developer- Mumbai
# 42                        Dot Net Developer in Flight/Hotel Api Integration
# 43                                                        Android Developer
# 44                                                    Android App Developer
# 45                                                 Junior Android Developer
# 46                                                        Android Developer
# 47                                                        Android Developer
# 48                                                        Android Developer
# 49                                                        Android Developer
# 50                                                    Jr. Android Developer
# 51                                                        Android Developer
# 52                                                        Android Developer
# 53      Java, J2EE, Javascript, Mobile Developer (PHP developers can apply)
# 54                                                        Android Developer
# 55                                      Web & ionic Developer (Exp: 2-4yrs)
# 56                 IBM Worklight (MobileFirst) Mobile Application Developer
# 57                                                  IBM Worklight Developer
# 58            Urgent Opening for Mobile App Developer (Android/iOS/Windows)
# 59                Software Developer - (.NetMVC) (PHP Codigniter) (Android)
# 60                              Immediate Joiner required-Android developer
# 61                                                        Android Developer
# 62                             Android Developer for Pune, Hinjewadi office
# 63                                Job opening for Android Developer (Warje)
# 64  Experienced .net developer and android developer required Full time JOB
# 65                                                        Android Developer
# 66                                                        Android Developer
# 67                                               Android Developer Required
# 68                                                        Android Developer
# 69                                                    iOS Developer Fresher
#
#                                                                                                                                                                                                    job_desc  \
# 0   Core Java Developer\r\r\n\r\r\nJob Description:\r\r\n\r\r\nAt Micro Focus, everything we do is based on a simple idea: The fastest way to get results is to build on what you have. Our software sol...
# 1   Job Summary\r\r\nOver 3 years experience designing, developing, integrating, and supporting Android App development\r\r\nApply in-depth understanding of business and IT requirements to streamline ...
# 2   Company Introduction\r\r\nApplied Materials , Inc. is the global leader in materials engineering solutions for the semiconductor, flat panel display and solar photovoltaic (PV) industries. applied...
# 3   Senior Mobile App Developer/Lead (Android or iOS)\r\r\nShaw Academy is seeking a Mobile Development Lead, initially to be the hands-on coder for our apps and then to build a team aroundyou. The ro...
# 4   Job Summary\r\r\nPosition: Android developer\r\r\nEducation: Bachelor's\r\r\nRequired candidates: Freshers\r\r\nResponsibilities and Duties\r\r\nDesign and build advanced applications for the Andr...
# 5   Job Summary\r\r\nWe are looking for an Android developer responsible for the development and maintenance of applications aimed at a vast number of diverse Android devices. Following are the requir...
# 6   We are looking for an Android Developer who possesses a passion for pushing mobile technologies to the limits. This Android app developer will work with our team of talented engineers to design an...
# 7   Job Summary\r\r\nLooking for a Android Developer for Bangalore Location\r\r\nResponsibilities and Duties\r\r\nJob description\r\r\nImplementing, and enhancing the Android mobile application.\r\r\n...
# 8   As an Android Developer you will be responsible for design and development of Android applications. You must be comfortable with Android Studios and knowledgable of latest Android SDK including An...
# 9   Responsibilities and Duties\r\r\n* Design and build advanced applications for the Android platform\r\r\n* Collaborate with cross-functional teams to define, design, and ship new features\r\r\n* Wo...
# 10  Job Summary\r\r\nWe are looking for a talented mobile app expert to lead our mobile team. The ideal candidate will be able to pitch custom mobile app projects to existing clients as well as be han...
# 11  Job Summary\r\r\nWe are looking for an Android Developer who possesses a passion for mobile technologies and will work as an individual contributor to build the company's mobile platform. We are l...
# 12  Job Summary\r\r\nAndroid developer with 2 to 5 years of experience.\r\r\nAdditional iOS experience preferred\r\r\nJob Type: Full-time\r\r\nSalary: ₹500,000.00 to ₹900,000.00 /year\r\r\nExperience:...
# 13  Job Summary\r\r\nWe are looking for an Android Developer who possesses a passion for pushing mobile technologies to the limits. This Android app developer will work with our team of talented engin...
# 14  Job Summary\r\r\nAither Technology is looking for a talented Senior Android Developer to help grow our new office in Bangalore, India. We are a US based software development services business that...
# 15  Job Summary\r\r\nTechnologies needed: Android and PHP. Should have worked hands-on on MySQL and should have some exposure to SDK integration, UI/UX creation & integration. Knowledge or exposure to...
# 16  Job Summary\r\r\n***Laravel & PHP Developer***\r\r\nExperience in developing web-based applications in MVC architecture - Laravel Preferred\r\r\nGood knowledge of Mysql and query optimisation\r\r\...
# 17  Experience of working with Web Services, XML , JSON\r\r\nExperience of working with multi-language, multi-screen resolutions\r\r\nExperience of working with Social Network Integration ( FaceBook ,...
# 18  Responsibilities and Duties\r\r\nJob Description:\r\r\nSound Technical Expertise in Core Java - Android, XML, JSON, SOAP & Android Native\r\r\nExperience with Android SDK & Android Tools framework...
# 19  Strong knowledge of OOPs, Java.\r\r\nWorking knowledge of Android SDK, Restful services, Angular/React.js, Database\r\r\nJob Types: Part-time, Internship, Fresher\r\r\nExperience:\r\r\nJava: 1 yea...
# 20  We are looking for an Android developer responsible for the development and maintenance of applications aimed at a vast number of diverse Android devices. Your primary focus will be the developmen...
# 21  Designing and developing advanced applications for the Android platform\r\r\nUnit-testing code for robustness, including edge cases, usability, and general reliability\r\r\nBug fixing and improvin...
# 22  Job Summary\r\r\nWe are looking for an Android Developer who possesses a passion for pushing mobile technologies to the limits. This Android app developer will work with our team of talented engin...
# 23  Requirements:\r\r\nBe smart and get things done and you have experience with shipping products on Android.\r\r\nHave shipped an Android app whether in a professional role or as a significant side ...
# 24  Highly Passionate Android Developer required for a mobile development studio based in New Delhi.\r\r\nJoin us as an Android Developer and help us to shape the future of the software Industry. You ...
# 25  Excellent knowledge in core Java\r\r\n* Hands on experience in the full life cycle of Android application development\r\r\n* Hands on experience in the Android Components.\r\r\n* Strong knowledge ...
# 26  Job Summary\r\r\nWe are looking for an Android developer responsible for the development and maintenance of applications aimed at a vast number of diverse Android devices. Your primary focus will ...
# 27  Design, build, test, deploy, maintain, and enhance android apps\r\r\nDesign and build apps using material design and knowledge on material design principles in different aspects.\r\r\nBug fixing a...
# 28  Wells Fargo & Company (NYSE: WFC) is a leading global financial services company with $2.0 trillion in assets and offices in over 37 countries. Founded in 1852 and headquartered in San Francisco, ...
# 29  Job Summary\r\r\nProgressive Web Apps Developer with Minimum 1 Year Experience\r\r\nResponsibilities and Duties\r\r\n1. Develop new PWA Apps\r\r\n2. Convert Existing Native Apps to PWA\r\r\nQualif...
# ..                                                                                                                                                                                                      ...
# 40  Job Summary\r\r\nWill be responsible for developing and maintaining mobile applications. Coordinate with the product team to set project timelines and improve existing products using customer feed...
# 41  Come be a part of our excellent work environment. Miles Technologies was named Winner of the The Philadelphia Business Journal 5 years in a row, Best Places to Work Award.\r\r\nMiles Technologies ...
# 42  Job Summary\r\r\nSr. Dot Net Developer with experience into flight/hotel booking\r\r\nCandidate must have done Api integration on Travel portal/project ie. Must have flight/hotel Api integration e...
# 43  Overview:\r\r\n\r\r\nWe are looking for an Android developer responsible for the development and maintenance of applications aimed at a vast number of diverse Android devices. Your primary focus w...
# 44  We're looking for an amazing, highly creative & fast forward android app developer who can design complete UI and take care of the development part. If that sounds like you, we would love to have ...
# 45  Required skillset and Experience: (0-1) Years\r\r\nSolid understanding of Android SDK and Android Studio\r\r\nMust have sound knowledge of Android architecture\r\r\nStrong Oops fundamentals, Java,...
# 46  Android Developer\r\r\nKeywords:\r\r\nAndroid mobile Application, Memory Management, Application Design, Application Development, GPS, GPRS, SDK\r\r\nExperience:\r\r\n1+ Years\r\r\nSalary:\r\r\n15...
# 47  Job Summary\r\r\nDesign and build advanced applications for the Android platform\r\r\nCollaborate with cross-functional teams to define, design, and ship new features\r\r\nWork with outside data s...
# 48  Job Summary\r\r\nWe are looking for an Android Developer who possesses a passion for pushing mobile technologies to the limits. This Android app developer will work with our team of talented engin...
# 49  Android developer with key development skills on android studio, objective c. Android developers should be having strong knowledge of Java and other latest Android tools. Agile working methods, re...
# 50  We are looking for an Android Developer who possesses a passion for pushing mobile technologies to the limits. This Android app developer will work with our team of talented engineers to design an...
# 51  Job Summary\r\r\nBuilding an app or reputable work in the field of Android.\r\r\nA passion for exploring Android and building excellent apps or SDKs\r\r\n- Familarity with Android SDK.\r\r\n- Work...
# 52  Android Developer\r\r\nLocation: Mumbai\r\r\nWe are looking for a passionate and a highly talented Android Developer to build our Mobile App.\r\r\nCore Responsibilities\r\r\nDevelop & maintain our...
# 53  Job Summary\r\r\nWe work on Java, Javascript, Mobile and Salesforce development with ample scope for learning multiple technologies.\r\r\nTechnology landscape for this positions is listed below\r\...
# 54  Job Summary\r\r\nWe are looking out for a Senior Android Developer who will be fully responsible for the maintenance & enhancement of our current applications and development of future Apps\r\r\nR...
# 55  Job Summary\r\r\nWe are looking for an android and Ionic developer responsible for developing Android based applications for our clients. The primary focus will be to build an android application ...
# 56  SkillSet: review, code, mobile, jira, android. Job Responsibilities Role and Responsibilities: Design and build responsive applications desktop, tablet and mobile devices. Work with offshore team ...
# 57  SkillSet: script, web, aspnet, console, tools. Job Responsibilities: 3 years of hands on Knowledge IBM MobileFirst . 2 years of hands on experience on Angular 2/4 and ionic frameworks for Mobile A...
# 58  No. of Job opening 3\r\r\nFunctional Area IT\r\r\nIndustry Type IT-Software-Software Services\r\r\nKeywords android,iOS,windows,sdk,\r\r\nWe are looking for Android developer, iOS developer and Wi...
# 59  Job Summary\r\r\n**\r\r\n.NET MVC Developer\r\r\nASP.Net Using C# , Microsoft .NET 3.5/4.5 , MVC, XHTML, CSS, XML,\r\r\nKnowledge of jQuery and Angular JS is a plus\r\r\nMicrosoft SQL Server 2005/...
# 60  Android 1-3 years immediate joiners Notice Max 10-15 days\r\r\n·Proven software development experience and Android skills development\r\r\n·Proven working experience in Android app development and...
# 61  Job Summary:\r\r\nShould have strong fundamental knowledge of Android development.\r\r\nGood understanding of web services/REST API\r\r\nGood understanding of Google and other API\r\r\nIntegrating...
# 62  Android developer with upto 5 years experience\r\r\n\r\r\nExperience developing, enhancing and deploying mobile applications\r\r\nDevelopment using Android framework and Eclipse\r\r\nExperience wi...
# 63  Job Summary\r\r\nLooking for a Android Developer who possesses a passion for pushing mobile technologies to the limits.\r\r\nThis Android app developer will work with our team of talented engineer...
# 64  Job Summary\r\r\nStrong knowledge of Android SDK, different versions of Android, and how to deal with different screen sizes\r\r\nFamiliarity with RESTful APIs to connect Android applications to b...
# 65  1) Experience in building 2-7 android mobile apps in JAVA & Android Studio\r\r\n2) Must have good understanding of JAVA, OOPS, SQLite, Android SDK, Rest/SOAP/JSON/XML parsing.\r\r\n3) Hands on exp...
# 66  Your rolewill include implementing, and enhancing the Androidmobile application, alongside a team of world-class developers, designers and software architects. You will be responsible for choosing...
# 67  We are looking for android Developer on immediate.\r\r\nRequired in .. Android studio,Elips\r\r\nExperience ......0 to 1 year\r\r\nWalk in ;.......... 3.6.2019 to 18.6.2019\r\r\nSkills..... Abilit...
# 68  SkillSet: script, web, nodejs, requirements, aspnet. Designing and building solutions for banking / financial domain. Translates business requirements into technical details relevant to web applic...
# 69  Fresher to 1 year experience for Full Stack iOS Development. For Cloud & Mobile based SaaS Product Development\r\r\nEduCloud is Pune based Product development startup company.\r\r\nWe are looking ...
#
#              job_type
# 0   Android Developer
# 1   Android Developer
# 2   Android Developer
# 3   Android Developer
# 4   Android Developer
# 5   Android Developer
# 6   Android Developer
# 7   Android Developer
# 8   Android Developer
# 9   Android Developer
# 10  Android Developer
# 11  Android Developer
# 12  Android Developer
# 13  Android Developer
# 14  Android Developer
# 15  Android Developer
# 16  Android Developer
# 17  Android Developer
# 18  Android Developer
# 19  Android Developer
# 20  Android Developer
# 21  Android Developer
# 22  Android Developer
# 23  Android Developer
# 24  Android Developer
# 25  Android Developer
# 26  Android Developer
# 27  Android Developer
# 28  Android Developer
# 29  Android Developer
# ..                ...
# 40  Android Developer
# 41  Android Developer
# 42  Android Developer
# 43  Android Developer
# 44  Android Developer
# 45  Android Developer
# 46  Android Developer
# 47  Android Developer
# 48  Android Developer
# 49  Android Developer
# 50  Android Developer
# 51  Android Developer
# 52  Android Developer
# 53  Android Developer
# 54  Android Developer
# 55  Android Developer
# 56  Android Developer
# 57  Android Developer
# 58  Android Developer
# 59  Android Developer
# 60  Android Developer
# 61  Android Developer
# 62  Android Developer
# 63  Android Developer
# 64  Android Developer
# 65  Android Developer
# 66  Android Developer
# 67  Android Developer
# 68  Android Developer
# 69  Android Developer
#
# [70 rows x 3 columns]

# %% [markdown]
# ### Retain alphabets/remove unnecessary space
# Now, we will perform some simple preprocessing on the job description column(i.e `job_desc`) in order to make them more amenable for analysis. We will use a regular expression to retain only alphabets in the description and remove unnecessary space.

# %% [markdown]
# ### Exploratory Analysis: Plot the word cloud of the most common words
# In order to verify whether the preprocessing happened correctly, we can make a word cloud of the text of the job descriptions. This will give us a visual representation of the most common words. Visualization is key to understanding whether we are still on the right track! In addition, it allows us to verify whether we need additional preprocessing before further analyzing the text data. Python has a massive number of open libraries! Instead of trying to develop a method to create word clouds ourselves, we'll use Andreas Mueller's wordcloud library

# %% [markdown]
# ### Let's remove some common words that every job description contain. A common words list is provided to you(you can add more). Display top 10 most occuring words.
# LDA does not work directly on text data. First, it is necessary to convert the documents into a simple vector representation. This representation will then be used by LDA to determine the topics. Each entry of a 'document vector' will correspond with the number of times a word occurred in the document.

# %% [markdown]
# It seems that now most frequent terms in our data are relevant.

# %% [markdown]
# ### Perform lowercasing and calculate the frequency of top 10  words.

# %% [markdown]
# ### Model buliding with LSA

# %% [markdown]
# ### Model buliding with LDA
#
# In LSA we saw that Topic 1 has some different words which are not related to the Journalist job. Lets see if we can improve our topics by using LDA algorithm.

# %% [markdown]
# ### Analyzing with LDA model
#
# To visualize the topics in a 2-dimensional space we will use the pyLDAvis library. This visualization is interactive in nature and displays topics along with the most relevant words.
#
# pyLDAvis package is designed to help users interpret the topics in a topic model that has been fit to a corpus of text data. The interactive visualization pyLDAvis produces is helpful for both:
#
# 1. Better understanding and interpreting individual topics, and
# 2. Better understanding the relationships between the topics.
#
# For (1), you can manually select each topic to view its top most freqeuent and/or “relevant” terms, using different values of the λ parameter. This can help when you’re trying to assign a human interpretable name or “meaning” to each topic.
#
# For (2), exploring the Intertopic Distance Plot can help you learn about how topics relate to each other, including potential higher-level structure between groups of topics.
#
#
# Here is the documentation for <a href="https://pyldavis.readthedocs.io/en/latest/readme.html">pyLDAvis</a>
