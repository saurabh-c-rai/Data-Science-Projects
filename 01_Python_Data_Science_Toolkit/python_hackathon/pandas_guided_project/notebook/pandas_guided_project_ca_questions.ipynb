# %% [markdown]
# # Sales report using Pandas
# ***
# ## Problem Statement
#
# Hello budding Data Scientists. We have with us a bank data set which gives information about the revenue of various customers spread across different regions in USA.
#
# Using the knowledge of Pandas and Matplotlib, we will try to answer certain questions from the bank dataset
#
# We will also then scrape certain additional data from Wikipedia, clean it and combine it with our bank data for better understandability of the data.
#
#
# ## About the Dataset
#
# Preview of the dataset
#
# ![bank_dataset](../images/bank_data.png)
#
# The dataset has details of 15 customers with following 9 features.
#
# |Feature|Description|
# |-----|-----|
# |account|account Id|
# |name|name of the person|
# |street|Name of the street|
# |city|Name of the city|
# |state|Name of the state|
# |postal-code|numerical value|
# |Jan|Amount in doller|
# |Feb|Amount in doller|
# |Mar|Amount in doller|
#
#
#
#
# ## Why solve this project
#
# Doing this project will enable you to integrate Multiple data sources to answer basic questions. You will also learn to perform common excel tasks with pandas
#
# What will you learn in the session ?
# Python Basics
# Pandas
# Web Scrapping
# Functions
# Plotting
# Pre-requisites
# Working knowledge of Pandas, Numpy, Matplotlib
# Data indexing and slicing

# %% [markdown]
# # Load Data and Compute total
# The first step - you know the drill by now - load the dataset and see how it looks like. Additionally, calculate the total amount in the first quarter of the financial year. Calculate the total amount of all the users for the month of jan, feb and Mar and also grand total.
#
#
# ## Instructions
#
# - Load dataset using pandas read_csv api in variable `df` and give file path as `path`.
# - The names of the states `state` column are changed to lower case and store it in `df['state']`
# - Create a new column named `total` which computes the total amount in the first quarter
#   of the financial year i.e. for the months of Jan, Feb and Mar and store it in `df['total']`
# - Calculate the sum of amount of all users in the Month of Jan, Feb, March and store it in variable `sum_row`
#  (Here the sum implies the sum of all the entries in the `Jan Column`, sum of entries in `Feb` Column and Grand total stands for the sum of entries in the column `total`)
# - Append this computed sum to the DataFrame `df_final`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Code starts here
path = '/Users/raisaurabh04/OneDrive/GreyAtom/Data Science/GitHub/GLabs_DSMP/01_Python_Data_Science_Toolkit/python_hackathon/pandas_guided_project/data'
df = pd.read_csv(path +'/excel-comp-data.csv', sep = ',', header = 0)
df['state'] = df['state'].str.lower()
df['total'] = df['Jan'] + df['Feb'] + df['Mar']

sum_row = df[['Jan', 'Feb', 'Mar', 'total']].sum()

df_final = df.append(sum_row, ignore_index = True)
df_final

#Code ends here
# Out:
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# 1                      1311 Alvis Tunnel      Port Khadijah  northcarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          maine
# 4                    7274 Marissa Common    Shanahanchester     california
# 5                   89403 Casimer Spring       Jeremieburgh       arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    rhodeisland
# 8                       26739 Grant Lock    Lake Juliannton   pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       tenessee
# 11              18115 Olivine Throughway      Norbertomouth    northdakota
# 12                       182 Bertie Road        East Davian           iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    rhodeisland
# 14                 8917 Bergstrom Meadow    Kathryneborough       delaware
# 15                                   NaN                NaN            NaN
#
#     postal-code        Jan        Feb       Mar      total
# 0       28752.0    10000.0    62000.0   35000.0   107000.0
# 1       38365.0    95000.0    45000.0   35000.0   175000.0
# 2       76517.0    91000.0   120000.0   35000.0   246000.0
# 3       46021.0    45000.0   120000.0   10000.0   175000.0
# 4       49681.0   162000.0   120000.0   35000.0   317000.0
# 5       62785.0   150000.0   120000.0   35000.0   305000.0
# 6       18008.0    62000.0   120000.0   70000.0   252000.0
# 7       53461.0   145000.0    95000.0   35000.0   275000.0
# 8       64415.0    70000.0    95000.0   35000.0   200000.0
# 9       46308.0    70000.0   120000.0   35000.0   225000.0
# 10      47743.0    45000.0   120000.0   55000.0   220000.0
# 11      31415.0   150000.0    10000.0  162000.0   322000.0
# 12      72686.0   162000.0   120000.0   35000.0   317000.0
# 13      31919.0    55000.0   120000.0   35000.0   210000.0
# 14      27933.0   150000.0   120000.0   70000.0   340000.0
# 15          NaN  1462000.0  1507000.0  717000.0  3686000.0

# %% [markdown]
# # Scrape Data From the web
#
# Here, you will be scraping data from the web and cleaning it.
#
#
# ## Instructions:
#
# - Scrapes the url `https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations` and store it in variable `url`
# - Use module `requests` to `get` the url and store it in variable called `response`
# - load the html file in dataframe `df1`. `Note`:use `pd.read_html(response.content)[0]`.
# - First few rows consists of unclean data. You need to select rows from index 11 till end. Make the values at index 11 as column headers and store it in dataframe `df1`.
# - Remove space from the column named 'United States of America' and store the result in dataframe called `df1['United States of America']`

# %%
import requests

# Code starts here
url = 'https://en.wikipedia.org/wiki/List_of_U.S._state_abbreviations'
response = requests.get(url)
# Code ends here

# %%
df = pd.read_html(response.content)[0]
df
# Out:
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP)  \
# 0                                              Codes:
# 1                                                 ISO
# 2                                                ANSI
# 3                                                USPS
# 4                                                USCG
# 5                                      Abbreviations:
# 6                                                 GPO
# 7                                                  AP
# 8                           Name and status of region
# 9                                                 NaN
# 10                           United States of America
# 11                                            Alabama
# 12                                             Alaska
# 13                                            Arizona
# 14                                           Arkansas
# 15                                         California
# 16                                           Colorado
# 17                                        Connecticut
# 18                                           Delaware
# 19                               District of Columbia
# 20                                            Florida
# 21                                            Georgia
# 22                                             Hawaii
# 23                                              Idaho
# 24                                           Illinois
# 25                                            Indiana
# 26                                               Iowa
# 27                                             Kansas
# 28                                           Kentucky
# 29                                          Louisiana
# ..                                                ...
# 58                                         Washington
# 59                                      West Virginia
# 60                                          Wisconsin
# 61                                            Wyoming
# 62                                     American Samoa
# 63                                               Guam
# 64                           Northern Mariana Islands
# 65                                        Puerto Rico
# 66                                U.S. Virgin Islands
# 67                        U.S. Minor Outlying Islands
# 68                                       Baker Island
# 69                                     Howland Island
# 70                                      Jarvis Island
# 71                                     Johnston Atoll
# 72                                       Kingman Reef
# 73                                     Midway Islands
# 74                                     Navassa Island
# 75                                   Palmyra Atoll[c]
# 76                                        Wake Island
# 77                                         Micronesia
# 78                                   Marshall Islands
# 79                                              Palau
# 80                    U.S. Armed Forces – Americas[d]
# 81                      U.S. Armed Forces – Europe[e]
# 82                     U.S. Armed Forces – Pacific[f]
# 83                           Northern Mariana Islands
# 84                                  Panama Canal Zone
# 85                                           Nebraska
# 86                                 Philippine Islands
# 87             Trust Territory of the Pacific Islands
#
#    Codes:  ISO ISO 3166 codes (2-letter, 3-letter, and 3-digit codes from ISO 3166-1; 2+2-letter codes from ISO 3166-2)  ANSI 2-letter and 2-digit codes from the ANSI standard INCITS 38:2009  USPS 2-letter codes used by the United States Postal Service  USCG 2-letter codes used by the United States Coast Guard (red text shows differences between ANSI and USCG) Abbreviations:  GPO Older variable-length official US Government Printing Office abbreviations  AP Abbreviations from the AP Stylebook (red text shows differences between GPO and AP).1  \
# 0                                              Codes:
# 1   ISO 3166 codes (2-letter, 3-letter, and 3-digi...
# 2   2-letter and 2-digit codes from the ANSI stand...
# 3   2-letter codes used by the United States Posta...
# 4   2-letter codes used by the United States Coast...
# 5                                      Abbreviations:
# 6   Older variable-length official US Government P...
# 7   Abbreviations from the AP Stylebook (red text ...
# 8                           Name and status of region
# 9                                                 NaN
# 10                                      Federal state
# 11                                              State
# 12                                              State
# 13                                              State
# 14                                              State
# 15                                              State
# 16                                              State
# 17                                              State
# 18                                              State
# 19                                   Federal district
# 20                                              State
# 21                                              State
# 22                                              State
# 23                                              State
# ...
# 59                                     W.V., W. Virg.
# 60                                         Wi., Wisc.
# 61                                                Wy.
# 62                                                NaN
# 63                                                NaN
# 64                                            CNMI[2]
# 65                                                NaN
# 66                                           U.S.V.I.
# 67                                                NaN
# 68                                              XB[3]
# 69                                              XH[3]
# 70                                              XQ[3]
# 71                                              XU[3]
# 72                                              XM[3]
# 73                                              QM[3]
# 74                                              XV[3]
# 75                                              XL[3]
# 76                                              QW[3]
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
#
# [88 rows x 10 columns]

# %%
# df1.columns = ['United States of America','1', '2', 'Abbv', '4', 
#                 '5', '6', '7', '8', '9'] 

df = df.rename(columns=df.iloc[10])

# %%
df1 = df.iloc[11:].rename_axis('Index')

# %%
df1.loc[df1['United States of America'] == 'North Carolina']
# Out:
#       United States of America Federal state  \
# Index
# 44              North Carolina         State
#
#       .mw-parser-output .monospaced{font-family:monospace,monospace}USUSA840  \
# Index
# 44                                                 US-NC
#
#        US  00 NaN NaN  U.S.  U.S.   U.S.A.
# Index
# 44     NC  37  NC  NC  N.C.  N.C.  N. Car.

# %%
df1['United States of America'] = df1['United States of America'].apply(lambda x : x.replace(" ", ""))
df1
# Out:
#                 United States of America                Federal state  \
# Index
# 11                               Alabama                        State
# 12                                Alaska                        State
# 13                               Arizona                        State
# 14                              Arkansas                        State
# 15                            California                        State
# 16                              Colorado                        State
# 17                           Connecticut                        State
# 18                              Delaware                        State
# 19                    DistrictofColumbia             Federal district
# 20                               Florida                        State
# 21                               Georgia                        State
# 22                                Hawaii                        State
# 23                                 Idaho                        State
# 24                              Illinois                        State
# 25                               Indiana                        State
# 26                                  Iowa                        State
# 27                                Kansas                        State
# 28                              Kentucky         State (Commonwealth)
# 29                             Louisiana                        State
# 30                                 Maine                        State
# 31                              Maryland                        State
# 32                         Massachusetts         State (Commonwealth)
# 33                              Michigan                        State
# 34                             Minnesota                        State
# 35                           Mississippi                        State
# 36                              Missouri                        State
# 37                               Montana                        State
# 38                              Nebraska                        State
# 39                                Nevada                        State
# 40                          NewHampshire                        State
# ...                                  ...                          ...
# 58                            Washington                        State
# 59                          WestVirginia                        State
# 60                             Wisconsin                        State
# 61                               Wyoming                        State
# 62                         AmericanSamoa     Insular area (Territory)
# 63                                  Guam     Insular area (Territory)
# 64                NorthernMarianaIslands  Insular area (Commonwealth)
# 65                            PuertoRico     Insular area (Territory)
# 66                     U.S.VirginIslands     Insular area (Territory)
# 67              U.S.MinorOutlyingIslands                Insular areas
# 68                           BakerIsland                       island
# 69                         HowlandIsland                       island
# 70                          JarvisIsland                       island
# 71                         JohnstonAtoll                        atoll
# 72                           KingmanReef                        atoll
# 73                         MidwayIslands                        atoll
# 74                         NavassaIsland                       island
# 75                       PalmyraAtoll[c]                     atoll[c]
# 76                            WakeIsland                        atoll
# 77                            Micronesia      Freely associated state
# 78                       MarshallIslands      Freely associated state
# 79                                 Palau      Freely associated state
# 80           U.S.ArmedForces–Americas[d]        US military mail code
# 81             U.S.ArmedForces–Europe[e]        US military mail code
# 82            U.S.ArmedForces–Pacific[f]        US military mail code
# 83                NorthernMarianaIslands      Obsolete postal code[g]
# 84                       PanamaCanalZone         Obsolete postal code
# 85                              Nebraska      Obsolete postal code[h]
# 86                     PhilippineIslands         Obsolete postal code
# 87     TrustTerritoryofthePacificIslands         Obsolete postal code
#
#       .mw-parser-output .monospaced{font-family:monospace,monospace}USUSA840  \
# Index
# 11                                                 US-AL
# 12                                                 US-AK
# 13                                                 US-AZ
# 14                                                 US-AR
# 15                                                 US-CA
# 16                                                 US-CO
# 17                                                 US-CT
# 18                                                 US-DE
# 19                                                 US-DC
# 20                                                 US-FL
# 21                                                 US-GA
# 22                                                 US-HI
# 23                                                 US-ID
# 24                                                 US-IL
# 25                                                 US-IN
# 26                                                 US-IA
# 27                                                 US-KS
# 28                                                 US-KY
# 29                                                 US-LA
# 30                                                 US-ME
# 31                                                 US-MD
# 32                                                 US-MA
# 33                                                 US-MI
# 34                                                 US-MN
# 35                                                 US-MS
# 36                                                 US-MO
# 37                                                 US-MT
# 38                                                 US-NE
# 39                                                 US-NV
# 40                                                 US-NH
# ...                                                  ...
# 58                                                 US-WA
# 59                                                 US-WV
# 60                                                 US-WI
# 61                                                 US-WY
# 62                                         ASASM016US-AS
# 63                                         GUGUM316US-GU
# 64                                         MPMNP580US-MP
# 65                                         PRPRI630US-PR
# 66                                         VIVIR850US-VI
# 67                                         UMUMI581US-UM
# 68                                                 UM-81
# 69                                                 UM-84
# 70                                                 UM-86
# 71                                                 UM-67
# 72                                                 UM-89
# 73                                                 UM-71
# 74                                                 UM-76
# 75                                                 UM-95
# 76                                                 UM-79
# 77                                              FMFSM583
# 78                                              MHMHL584
# 79                                              PWPLW585
# 80                                                   NaN
# 81                                                   NaN
# 82                                                   NaN
# 83                                                   NaN
# 84                                              PZPCZ594
# 85                                                   NaN
# 86                                           PHPHL608[4]
# 87                                              PCPCI582
#
#         US   00  NaN  NaN    U.S.    U.S.             U.S.A.
# Index
# 11      AL   01   AL   AL    Ala.    Ala.                NaN
# 12      AK   02   AK   AK  Alaska  Alaska              Alas.
# 13      AZ   04   AZ   AZ   Ariz.   Ariz.                Az.
# 14      AR   05   AR   AR    Ark.    Ark.                NaN
# 15      CA   06   CA   CF  Calif.  Calif.          Ca., Cal.
# 16      CO   08   CO   CL   Colo.   Colo.               Col.
# 17      CT   09   CT   CT   Conn.   Conn.                Ct.
# 18      DE   10   DE   DL    Del.    Del.                De.
# 19      DC   11   DC   DC    D.C.    D.C.         Wash. D.C.
# 20      FL   12   FL   FL    Fla.    Fla.         Fl., Flor.
# 21      GA   13   GA   GA     Ga.     Ga.               Geo.
# 22      HI   15   HI   HA  Hawaii  Hawaii               H.I.
# 23      ID   16   ID   ID   Idaho   Idaho          Id., Ida.
# 24      IL   17   IL   IL    Ill.    Ill.  Il., Ills., Ill's
# 25      IN   18   IN   IN    Ind.    Ind.                In.
# 26      IA   19   IA   IA    Iowa    Iowa       Ia., Ioa.[a]
# 27      KS   20   KS   KA   Kans.    Kan.           Ks., Ka.
# 28      KY   21   KY   KY     Ky.     Ky.     Ken., Kent.[b]
# 29      LA   22   LA   LA     La.     La.                NaN
# 30      ME   23   ME   ME   Maine   Maine                Me.
# 31      MD   24   MD   MD     Md.     Md.                NaN
# 32      MA   25   MA   MS   Mass.   Mass.                NaN
# 33      MI   26   MI   MC   Mich.   Mich.                NaN
# 34      MN   27   MN   MN   Minn.   Minn.                Mn.
# 35      MS   28   MS   MI   Miss.   Miss.                NaN
# 36      MO   29   MO   MO     Mo.     Mo.                NaN
# 37      MT   30   MT   MT   Mont.   Mont.                NaN
# 38      NE   31   NE   NB   Nebr.    Neb.                NaN
# 39      NV   32   NV   NV    Nev.    Nev.                Nv.
# 40      NH   33   NH   NH    N.H.    N.H.                NaN
# ...    ...  ...  ...  ...     ...     ...                ...
# 58      WA   53   WA   WN   Wash.   Wash.        Wa., Wn.[1]
# 59      WV   54   WV   WV  W. Va.   W.Va.     W.V., W. Virg.
# 60      WI   55   WI   WS    Wis.    Wis.         Wi., Wisc.
# 61      WY   56   WY   WY    Wyo.    Wyo.                Wy.
# 62      AS   60   AS   AS    A.S.     NaN                NaN
# 63      GU   66   GU   GU    Guam     NaN                NaN
# 64      MP   69   MP   CM    M.P.     NaN            CNMI[2]
# 65      PR   72   PR   PR    P.R.     NaN                NaN
# 66      VI   78   VI   VI    V.I.     NaN           U.S.V.I.
# 67      UM   74  NaN  NaN     NaN     NaN                NaN
# 68     NaN   81  NaN  NaN     NaN     NaN              XB[3]
# 69     NaN   84  NaN  NaN     NaN     NaN              XH[3]
# 70     NaN   86  NaN  NaN     NaN     NaN              XQ[3]
# 71     NaN   67  NaN  NaN     NaN     NaN              XU[3]
# 72     NaN   89  NaN  NaN     NaN     NaN              XM[3]
# 73     NaN   71  NaN  NaN     NaN     NaN              QM[3]
# 74     NaN   76  NaN  NaN     NaN     NaN              XV[3]
# 75     NaN   95  NaN  NaN     NaN     NaN              XL[3]
# 76     NaN   79  NaN  NaN     NaN     NaN              QW[3]
# 77      FM   64   FM  NaN     NaN     NaN                NaN
# 78      MH   68   MH  NaN     NaN     NaN                NaN
# 79      PW   70   PW  NaN     NaN     NaN                NaN
# 80     NaN  NaN   AA  NaN     NaN     NaN                NaN
# 81     NaN  NaN   AE  NaN     NaN     NaN                NaN
# 82     NaN  NaN   AP  NaN     NaN     NaN                NaN
# 83     NaN  NaN   CM  NaN     NaN     NaN                NaN
# 84     NaN  NaN   CZ  NaN     NaN     NaN                NaN
# 85     NaN  NaN   NB  NaN     NaN     NaN                NaN
# 86     NaN  NaN   PI  NaN     NaN     NaN                NaN
# 87     NaN  NaN   TT  NaN     NaN     NaN                NaN
#
# [77 rows x 10 columns]

# %%
df1['United States of America'] = df1['United States of America'].apply(lambda x : x.lower())

# %%
df1.reset_index()
# Out:
#     Index           United States of America                Federal state  \
# 0      11                            alabama                        State
# 1      12                             alaska                        State
# 2      13                            arizona                        State
# 3      14                           arkansas                        State
# 4      15                         california                        State
# 5      16                           colorado                        State
# 6      17                        connecticut                        State
# 7      18                           delaware                        State
# 8      19                 districtofcolumbia             Federal district
# 9      20                            florida                        State
# 10     21                            georgia                        State
# 11     22                             hawaii                        State
# 12     23                              idaho                        State
# 13     24                           illinois                        State
# 14     25                            indiana                        State
# 15     26                               iowa                        State
# 16     27                             kansas                        State
# 17     28                           kentucky         State (Commonwealth)
# 18     29                          louisiana                        State
# 19     30                              maine                        State
# 20     31                           maryland                        State
# 21     32                      massachusetts         State (Commonwealth)
# 22     33                           michigan                        State
# 23     34                          minnesota                        State
# 24     35                        mississippi                        State
# 25     36                           missouri                        State
# 26     37                            montana                        State
# 27     38                           nebraska                        State
# 28     39                             nevada                        State
# 29     40                       newhampshire                        State
# ..    ...                                ...                          ...
# 47     58                         washington                        State
# 48     59                       westvirginia                        State
# 49     60                          wisconsin                        State
# 50     61                            wyoming                        State
# 51     62                      americansamoa     Insular area (Territory)
# 52     63                               guam     Insular area (Territory)
# 53     64             northernmarianaislands  Insular area (Commonwealth)
# 54     65                         puertorico     Insular area (Territory)
# 55     66                  u.s.virginislands     Insular area (Territory)
# 56     67           u.s.minoroutlyingislands                Insular areas
# 57     68                        bakerisland                       island
# 58     69                      howlandisland                       island
# 59     70                       jarvisisland                       island
# 60     71                      johnstonatoll                        atoll
# 61     72                        kingmanreef                        atoll
# 62     73                      midwayislands                        atoll
# 63     74                      navassaisland                       island
# 64     75                    palmyraatoll[c]                     atoll[c]
# 65     76                         wakeisland                        atoll
# 66     77                         micronesia      Freely associated state
# 67     78                    marshallislands      Freely associated state
# 68     79                              palau      Freely associated state
# 69     80        u.s.armedforces–americas[d]        US military mail code
# 70     81          u.s.armedforces–europe[e]        US military mail code
# 71     82         u.s.armedforces–pacific[f]        US military mail code
# 72     83             northernmarianaislands      Obsolete postal code[g]
# 73     84                    panamacanalzone         Obsolete postal code
# 74     85                           nebraska      Obsolete postal code[h]
# 75     86                  philippineislands         Obsolete postal code
# 76     87  trustterritoryofthepacificislands         Obsolete postal code
#
#    .mw-parser-output .monospaced{font-family:monospace,monospace}USUSA840  \
# 0                                               US-AL
# 1                                               US-AK
# 2                                               US-AZ
# 3                                               US-AR
# 4                                               US-CA
# 5                                               US-CO
# 6                                               US-CT
# 7                                               US-DE
# 8                                               US-DC
# 9                                               US-FL
# 10                                              US-GA
# 11                                              US-HI
# 12                                              US-ID
# 13                                              US-IL
# 14                                              US-IN
# 15                                              US-IA
# 16                                              US-KS
# 17                                              US-KY
# 18                                              US-LA
# 19                                              US-ME
# 20                                              US-MD
# 21                                              US-MA
# 22                                              US-MI
# 23                                              US-MN
# 24                                              US-MS
# 25                                              US-MO
# 26                                              US-MT
# 27                                              US-NE
# 28                                              US-NV
# 29                                              US-NH
# ..                                                ...
# 47                                              US-WA
# 48                                              US-WV
# 49                                              US-WI
# 50                                              US-WY
# 51                                      ASASM016US-AS
# 52                                      GUGUM316US-GU
# 53                                      MPMNP580US-MP
# 54                                      PRPRI630US-PR
# 55                                      VIVIR850US-VI
# 56                                      UMUMI581US-UM
# 57                                              UM-81
# 58                                              UM-84
# 59                                              UM-86
# 60                                              UM-67
# 61                                              UM-89
# 62                                              UM-71
# 63                                              UM-76
# 64                                              UM-95
# 65                                              UM-79
# 66                                           FMFSM583
# 67                                           MHMHL584
# 68                                           PWPLW585
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                           PZPCZ594
# 74                                                NaN
# 75                                        PHPHL608[4]
# 76                                           PCPCI582
#
#      US   00  NaN  NaN    U.S.    U.S.             U.S.A.
# 0    AL   01   AL   AL    Ala.    Ala.                NaN
# 1    AK   02   AK   AK  Alaska  Alaska              Alas.
# 2    AZ   04   AZ   AZ   Ariz.   Ariz.                Az.
# 3    AR   05   AR   AR    Ark.    Ark.                NaN
# 4    CA   06   CA   CF  Calif.  Calif.          Ca., Cal.
# 5    CO   08   CO   CL   Colo.   Colo.               Col.
# 6    CT   09   CT   CT   Conn.   Conn.                Ct.
# 7    DE   10   DE   DL    Del.    Del.                De.
# 8    DC   11   DC   DC    D.C.    D.C.         Wash. D.C.
# 9    FL   12   FL   FL    Fla.    Fla.         Fl., Flor.
# 10   GA   13   GA   GA     Ga.     Ga.               Geo.
# 11   HI   15   HI   HA  Hawaii  Hawaii               H.I.
# 12   ID   16   ID   ID   Idaho   Idaho          Id., Ida.
# 13   IL   17   IL   IL    Ill.    Ill.  Il., Ills., Ill's
# 14   IN   18   IN   IN    Ind.    Ind.                In.
# 15   IA   19   IA   IA    Iowa    Iowa       Ia., Ioa.[a]
# 16   KS   20   KS   KA   Kans.    Kan.           Ks., Ka.
# 17   KY   21   KY   KY     Ky.     Ky.     Ken., Kent.[b]
# 18   LA   22   LA   LA     La.     La.                NaN
# 19   ME   23   ME   ME   Maine   Maine                Me.
# 20   MD   24   MD   MD     Md.     Md.                NaN
# 21   MA   25   MA   MS   Mass.   Mass.                NaN
# 22   MI   26   MI   MC   Mich.   Mich.                NaN
# 23   MN   27   MN   MN   Minn.   Minn.                Mn.
# 24   MS   28   MS   MI   Miss.   Miss.                NaN
# 25   MO   29   MO   MO     Mo.     Mo.                NaN
# 26   MT   30   MT   MT   Mont.   Mont.                NaN
# 27   NE   31   NE   NB   Nebr.    Neb.                NaN
# 28   NV   32   NV   NV    Nev.    Nev.                Nv.
# 29   NH   33   NH   NH    N.H.    N.H.                NaN
# ..  ...  ...  ...  ...     ...     ...                ...
# 47   WA   53   WA   WN   Wash.   Wash.        Wa., Wn.[1]
# 48   WV   54   WV   WV  W. Va.   W.Va.     W.V., W. Virg.
# 49   WI   55   WI   WS    Wis.    Wis.         Wi., Wisc.
# 50   WY   56   WY   WY    Wyo.    Wyo.                Wy.
# 51   AS   60   AS   AS    A.S.     NaN                NaN
# 52   GU   66   GU   GU    Guam     NaN                NaN
# 53   MP   69   MP   CM    M.P.     NaN            CNMI[2]
# 54   PR   72   PR   PR    P.R.     NaN                NaN
# 55   VI   78   VI   VI    V.I.     NaN           U.S.V.I.
# 56   UM   74  NaN  NaN     NaN     NaN                NaN
# 57  NaN   81  NaN  NaN     NaN     NaN              XB[3]
# 58  NaN   84  NaN  NaN     NaN     NaN              XH[3]
# 59  NaN   86  NaN  NaN     NaN     NaN              XQ[3]
# 60  NaN   67  NaN  NaN     NaN     NaN              XU[3]
# 61  NaN   89  NaN  NaN     NaN     NaN              XM[3]
# 62  NaN   71  NaN  NaN     NaN     NaN              QM[3]
# 63  NaN   76  NaN  NaN     NaN     NaN              XV[3]
# 64  NaN   95  NaN  NaN     NaN     NaN              XL[3]
# 65  NaN   79  NaN  NaN     NaN     NaN              QW[3]
# 66   FM   64   FM  NaN     NaN     NaN                NaN
# 67   MH   68   MH  NaN     NaN     NaN                NaN
# 68   PW   70   PW  NaN     NaN     NaN                NaN
# 69  NaN  NaN   AA  NaN     NaN     NaN                NaN
# 70  NaN  NaN   AE  NaN     NaN     NaN                NaN
# 71  NaN  NaN   AP  NaN     NaN     NaN                NaN
# 72  NaN  NaN   CM  NaN     NaN     NaN                NaN
# 73  NaN  NaN   CZ  NaN     NaN     NaN                NaN
# 74  NaN  NaN   NB  NaN     NaN     NaN                NaN
# 75  NaN  NaN   PI  NaN     NaN     NaN                NaN
# 76  NaN  NaN   TT  NaN     NaN     NaN                NaN
#
# [77 rows x 11 columns]

# %%
df1.loc[df1['United States of America'] == 'northcarolina']
# Out:
#       United States of America Federal state  \
# Index
# 44               northcarolina         State
#
#       .mw-parser-output .monospaced{font-family:monospace,monospace}USUSA840  \
# Index
# 44                                                 US-NC
#
#        US  00 NaN NaN  U.S.  U.S.   U.S.A.
# Index
# 44     NC  37  NC  NC  N.C.  N.C.  N. Car.

# %% [markdown]
# # Mapping Countries to their abbreviations
#
# Using the data scraped from the previous task, map abbriviation to the name of states.
#
#
#
# ## Instructions:
#
# - Using the scraped data create a variable called `mapping` which has the Country
#  as key and Abbreviation as value
# - Create a new column called `abbr` as the 7th column (index = 6) of the DataFrame `df_final`
# - map the `df_final['state']` on variable `mapping` and store it in `df_final['abbr']`

# %%
# Code Starts here
#df.set_index('ID').T.to_dict('list')
mapping = df1.set_index('United States of America')['US']

mapping = mapping.to_dict()

mapping

# Code ends here
# Out:
# {'alabama': 'AL',
#  'alaska': 'AK',
#  'arizona': 'AZ',
#  'arkansas': 'AR',
#  'california': 'CA',
#  'colorado': 'CO',
#  'connecticut': 'CT',
#  'delaware': 'DE',
#  'districtofcolumbia': 'DC',
#  'florida': 'FL',
#  'georgia': 'GA',
#  'hawaii': 'HI',
#  'idaho': 'ID',
#  'illinois': 'IL',
#  'indiana': 'IN',
#  'iowa': 'IA',
#  'kansas': 'KS',
#  'kentucky': 'KY',
#  'louisiana': 'LA',
#  'maine': 'ME',
#  'maryland': 'MD',
#  'massachusetts': 'MA',
#  'michigan': 'MI',
#  'minnesota': 'MN',
#  'mississippi': 'MS',
#  'missouri': 'MO',
#  'montana': 'MT',
#  'nebraska': nan,
#  'nevada': 'NV',
#  'newhampshire': 'NH',
#  'newjersey': 'NJ',
#  'newmexico': 'NM',
#  'newyork': 'NY',
#  'northcarolina': 'NC',
#  'northdakota': 'ND',
#  'ohio': 'OH',
#  'oklahoma': 'OK',
#  'oregon': 'OR',
#  'pennsylvania': 'PA',
#  'rhodeisland': 'RI',
#  'southcarolina': 'SC',
#  'southdakota': 'SD',
#  'tennessee': 'TN',
#  'texas': 'TX',
#  'utah': 'UT',
#  'vermont': 'VT',
#  'virginia': 'VA',
#  'washington': 'WA',
#  'westvirginia': 'WV',
#  'wisconsin': 'WI',
#  'wyoming': 'WY',
#  'americansamoa': 'AS',
#  'guam': 'GU',
#  'northernmarianaislands': nan,
#  'puertorico': 'PR',
#  'u.s.virginislands': 'VI',
#  'u.s.minoroutlyingislands': 'UM',
#  'bakerisland': nan,
#  'howlandisland': nan,
#  'jarvisisland': nan,
#  'johnstonatoll': nan,
#  'kingmanreef': nan,
#  'midwayislands': nan,
#  'navassaisland': nan,
#  'palmyraatoll[c]': nan,
#  'wakeisland': nan,
#  'micronesia': 'FM',
#  'marshallislands': 'MH',
#  'palau': 'PW',
#  'u.s.armedforces–americas[d]': nan,
#  'u.s.armedforces–europe[e]': nan,
#  'u.s.armedforces–pacific[f]': nan,
#  'panamacanalzone': nan,
#  'philippineislands': nan,
#  'trustterritoryofthepacificislands': nan}

# %%
df_final.insert(6, 'abbr', np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-bf9603e451a9> in <module>
# ----> 1 df_final.insert(6, 'abbr', np.nan)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert abbr, already exists

# %%
df_final['abbr'] = df_final['state'].map(mapping)

# %%
df_final
# Out:
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# 1                      1311 Alvis Tunnel      Port Khadijah  northcarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          maine
# 4                    7274 Marissa Common    Shanahanchester     california
# 5                   89403 Casimer Spring       Jeremieburgh       arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    rhodeisland
# 8                       26739 Grant Lock    Lake Juliannton   pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       tenessee
# 11              18115 Olivine Throughway      Norbertomouth    northdakota
# 12                       182 Bertie Road        East Davian           iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    rhodeisland
# 14                 8917 Bergstrom Meadow    Kathryneborough       delaware
# 15                                   NaN                NaN            NaN
#
#     postal-code abbr        Jan        Feb       Mar      total
# 0       28752.0   TX    10000.0    62000.0   35000.0   107000.0
# 1       38365.0   NC    95000.0    45000.0   35000.0   175000.0
# 2       76517.0   IA    91000.0   120000.0   35000.0   246000.0
# 3       46021.0   ME    45000.0   120000.0   10000.0   175000.0
# 4       49681.0   CA   162000.0   120000.0   35000.0   317000.0
# 5       62785.0   AR   150000.0   120000.0   35000.0   305000.0
# 6       18008.0  NaN    62000.0   120000.0   70000.0   252000.0
# 7       53461.0   RI   145000.0    95000.0   35000.0   275000.0
# 8       64415.0   PA    70000.0    95000.0   35000.0   200000.0
# 9       46308.0   ID    70000.0   120000.0   35000.0   225000.0
# 10      47743.0  NaN    45000.0   120000.0   55000.0   220000.0
# 11      31415.0   ND   150000.0    10000.0  162000.0   322000.0
# 12      72686.0   IA   162000.0   120000.0   35000.0   317000.0
# 13      31919.0   RI    55000.0   120000.0   35000.0   210000.0
# 14      27933.0   DE   150000.0   120000.0   70000.0   340000.0
# 15          NaN  NaN  1462000.0  1507000.0  717000.0  3686000.0

# %% [markdown]
# # Filling in the Missing Values
#
# What you will notice in the previous task is that for two states Mississippi and Tennessee will have NaN values in column `abbr`. In this task you will be filling those missing values manually.
#
#
#
# ## Intructions :
# - Locate the NaN in the abbr and replace `mississipi` with `MS` and store it in `df_mississipi`
# - Locate the NaN in the abbr and replace `tenessee` with `TN` and store it in `df_tenessee`
# - update the df_final

# %%
df_mississipi = df_final[df_final['state'] == 'mississipi'].replace(np.nan, 'MS')
df_mississipi
# Out:
#     account        name                        street               city  \
# 6  145068.0  Casper LLC  340 Consuela Bridge Apt. 400  Lake Gabriellaton
#
#         state  postal-code abbr      Jan       Feb      Mar     total
# 6  mississipi      18008.0   MS  62000.0  120000.0  70000.0  252000.0

# %%
df_tenessee = df_final[df_final['state'] == 'tenessee'].replace(np.nan, 'TN')
df_tenessee
# Out:
#      account                         name                     street  \
# 10  214098.0  Goodwin, Homenick and Jerde  649 Cierra Forks Apt. 078
#
#         city     state  postal-code abbr      Jan       Feb      Mar     total
# 10  Rosaberg  tenessee      47743.0   TN  45000.0  120000.0  55000.0  220000.0

# %%
df_final.replace(df_final.iloc[6], df_mississipi, inplace = True)    #replaced the entire row

# %%
df_final.replace(df_final.iloc[10], df_tenessee, inplace = True)

# %%
df_final
# Out:
#      account                              name  \
# 0   211829.0        Kerluke, Koepp and Hilpert
# 1   320563.0                    Walter-Trantow
# 2   648336.0        Bashirian, Kunde and Price
# 3   109996.0       D'Amore, Gleichner and Bode
# 4   121213.0                     Bauch-Goldner
# 5   132971.0  Williamson, Schumm and Hettinger
# 6   145068.0                        Casper LLC
# 7   205217.0                  Kovacek-Johnston
# 8   209744.0                    Champlin-Morar
# 9   212303.0                    Gerhold-Maggio
# 10  214098.0       Goodwin, Homenick and Jerde
# 11  231907.0                        Hahn-Moore
# 12  242368.0      Frami, Anderson and Donnelly
# 13  268755.0                       Walsh-Haley
# 14  273274.0                     McDermott PLC
# 15       NaN                               NaN
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          texas
# 1                      1311 Alvis Tunnel      Port Khadijah  northcarolina
# 2   62184 Schamberger Underpass Apt. 231     New Lilianland           iowa
# 3            155 Fadel Crescent Apt. 144         Hyattburgh          maine
# 4                    7274 Marissa Common    Shanahanchester     california
# 5                   89403 Casimer Spring       Jeremieburgh       arkansas
# 6           340 Consuela Bridge Apt. 400  Lake Gabriellaton     mississipi
# 7           91971 Cronin Vista Suite 601         Deronville    rhodeisland
# 8                       26739 Grant Lock    Lake Juliannton   pennsylvania
# 9              366 Maggio Grove Apt. 998          North Ras          idaho
# 10             649 Cierra Forks Apt. 078           Rosaberg       tenessee
# 11              18115 Olivine Throughway      Norbertomouth    northdakota
# 12                       182 Bertie Road        East Davian           iowa
# 13                  2624 Beatty Parkways       Goodwinmouth    rhodeisland
# 14                 8917 Bergstrom Meadow    Kathryneborough       delaware
# 15                                   NaN                NaN            NaN
#
#     postal-code abbr        Jan        Feb       Mar      total
# 0       28752.0   TX    10000.0    62000.0   35000.0   107000.0
# 1       38365.0   NC    95000.0    45000.0   35000.0   175000.0
# 2       76517.0   IA    91000.0   120000.0   35000.0   246000.0
# 3       46021.0   ME    45000.0   120000.0   10000.0   175000.0
# 4       49681.0   CA   162000.0   120000.0   35000.0   317000.0
# 5       62785.0   AR   150000.0   120000.0   35000.0   305000.0
# 6       18008.0   MS    62000.0   120000.0   70000.0   252000.0
# 7       53461.0   RI   145000.0    95000.0   35000.0   275000.0
# 8       64415.0   PA    70000.0    95000.0   35000.0   200000.0
# 9       46308.0   ID    70000.0   120000.0   35000.0   225000.0
# 10      47743.0   TN    45000.0   120000.0   55000.0   220000.0
# 11      31415.0   ND   150000.0    10000.0  162000.0   322000.0
# 12      72686.0   IA   162000.0   120000.0   35000.0   317000.0
# 13      31919.0   RI    55000.0   120000.0   35000.0   210000.0
# 14      27933.0   DE   150000.0   120000.0   70000.0   340000.0
# 15          NaN  NaN  1462000.0  1507000.0  717000.0  3686000.0

# %%
# # Code starts here
# #df_final['state'].where(df_final['state'] == 'mississipi')

# df_mississipi = df_final.loc[df_final['state'] == 'mississipi', 'abbr'] = 'MS'


# df_tenessee = df_final.loc[df_final['state'] == 'tenessee', 'abbr'] = 'TN'

# # Code ends here

# %% [markdown]
# ## Total amount bank hold
#
#
# Here, use the newly created abbr column to understand the total amount that the bank holds in each state. Let us make this data frame more readable by introducing units in this case `$` sign representing the unit of mone
#
#
#
# ## Instructions :
#
# - Groups by `abbr` and finds the sum of aabr,jan,feb ,mar and total store the result in `df_sub`
# - Write a `lambda function` to introduce `$` sign infromt of all the numbers using `applymap` and store the result in `formatted_df`

# %%
# Code starts here
df_sub = df_final.groupby('abbr')[['Jan', 'Feb', 'Mar', 'total']].sum()

# formatted_df = formatted_df.applymap(lambda x : '$' + str(x))

formatted_df = df_sub.applymap(lambda x : '${:,.0f}'.format(x))  #with proper formatting
formatted_df
# Code ends here
# Out:
#            Jan       Feb       Mar     total
# abbr
# AR    $150,000  $120,000   $35,000  $305,000
# CA    $162,000  $120,000   $35,000  $317,000
# DE    $150,000  $120,000   $70,000  $340,000
# IA    $253,000  $240,000   $70,000  $563,000
# ID     $70,000  $120,000   $35,000  $225,000
# ME     $45,000  $120,000   $10,000  $175,000
# MS     $62,000  $120,000   $70,000  $252,000
# NC     $95,000   $45,000   $35,000  $175,000
# ND    $150,000   $10,000  $162,000  $322,000
# PA     $70,000   $95,000   $35,000  $200,000
# RI    $200,000  $215,000   $70,000  $485,000
# TN     $45,000  $120,000   $55,000  $220,000
# TX     $10,000   $62,000   $35,000  $107,000

# %% [markdown]
# # Append a row to the DataFrame
#
# In this task, you will append a row to the data frame which will give us information about the total amount of the various regions in Jan, Feb and march and also the grand total
#
# ## Instructions :
#
# - Computes the sum of amount of all users in the Month of Jan, Feb, March and the  total in variable called `sum_row`
#  (Here the sum implies the sum of all the entries in the `Jan Column`, sum of entries in `Feb` Column and Grand total stands for the sum of entries in the column `total`)
# - Tranpose the dataframe `sum_row` and store it in new dataframe `df_sub_sum`
# - Make sure you append the `$` to all the digits and store it in dataframe `df_sub_sum` .
# - Append this computed sum to the DataFrame `final_table`
# - rename the index of `final_table` to  `{0: "Total"}`

# %%
# Code starts here
sum_row = df_sub[['Jan', 'Feb', 'Mar', 'total']].sum()
df_sum_row = pd.DataFrame(data = sum_row).T
df_sum_row
# Code ends here
# Out:
#          Jan        Feb       Mar      total
# 0  1462000.0  1507000.0  717000.0  3686000.0

# %%
df_sum_row = df_sum_row.applymap(lambda x : '${:,.0F}'.format(x))
df_sum_row
# Out:
#           Jan         Feb       Mar       total
# 0  $1,462,000  $1,507,000  $717,000  $3,686,000

# %%
final_table = formatted_df.append(df_sum_row)

# %%
final_table.rename(index = {0 : 'Total'}, inplace = True)
final_table
# Out:
#               Jan         Feb       Mar       total
# AR       $150,000    $120,000   $35,000    $305,000
# CA       $162,000    $120,000   $35,000    $317,000
# DE       $150,000    $120,000   $70,000    $340,000
# IA       $253,000    $240,000   $70,000    $563,000
# ID        $70,000    $120,000   $35,000    $225,000
# ME        $45,000    $120,000   $10,000    $175,000
# MS        $62,000    $120,000   $70,000    $252,000
# NC        $95,000     $45,000   $35,000    $175,000
# ND       $150,000     $10,000  $162,000    $322,000
# PA        $70,000     $95,000   $35,000    $200,000
# RI       $200,000    $215,000   $70,000    $485,000
# TN        $45,000    $120,000   $55,000    $220,000
# TX        $10,000     $62,000   $35,000    $107,000
# Total  $1,462,000  $1,507,000  $717,000  $3,686,000

# %% [markdown]
# # Pie chart for total
#
#
# Having prepared all the data now its time to present the results visually
#
# ## Instructions :
# - add the total of all the three months and store it in variable called `df_sub['total']`
# - plot the pie chart for the `df_sub['total']`

# %%
# Code starts here


# Code ends here
